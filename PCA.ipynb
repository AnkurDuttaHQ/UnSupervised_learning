# %%
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = load_iris()
X = data.data
y = data.target

# %%
df = pd.DataFrame(data.data , columns=data.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
X = pd.DataFrame(data.data)
X
# Out:
#        0    1    2    3
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...
# 145  6.7  3.0  5.2  2.3
# 146  6.3  2.5  5.0  1.9
# 147  6.5  3.0  5.2  2.0
# 148  6.2  3.4  5.4  2.3
# 149  5.9  3.0  5.1  1.8
#
# [150 rows x 4 columns]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
## impliment pca
from sklearn.decomposition import PCA
pca = PCA(n_components=2,random_state=42)
X_pca = pca.fit_transform(X_scaled)

# %%
X_pca.shape
# Out:
# (150, 2)

# %%
print("which principal component carries how much variance:",pca.explained_variance_ratio_)
# Out:
# which principal component carries how much variance: [0.72962445 0.22850762]

# %%
## Visualize our data 
plt.figure(figsize=(8,6))
sns.scatterplot(
    x=X_pca[:,0],
    y=X_pca[:,1],
    c=y
)
# Out:
# <Axes: >
